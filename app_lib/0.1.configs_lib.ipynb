# %%
raw_folder = "abfss://raw@f1datalakestorage.dfs.core.windows.net"
processed_folder = "abfss://processed@f1datalakestorage.dfs.core.windows.net"
prsentation_folder = "abfss://presentation@f1datalakestorage.dfs.core.windows.net"

# %%
from pyspark.sql.functions import current_timestamp
def populate_ingestion_time(df):
    df = df.withColumn("ingestion_time", current_timestamp())
    return df
